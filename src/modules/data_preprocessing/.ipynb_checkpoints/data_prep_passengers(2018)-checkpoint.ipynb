# %%
import pandas as pd
import numpy as np

# %%
#import data into dataframe
df_passengers_raw = pd.read_csv('../../../data/raw_data/passengers(2018).csv')
df_passengers_raw.head()
# Out:
#    departures_scheduled  departures_performed  payload  seats  passengers  \
# 0                     0                    22  1703680   6534        6096
# 1                     2                     2    28740    140          31
# 2                    30                    30   383250   1500        1215
# 3                     1                     1    11118     50          45
# 4                    58                    58  1020800   3734        2591
#
#    freight  mail  distance  ramp_to_ramp  air_time  ... dest_country  \
# 0   160360     0      5681             0         0  ...           US
# 1        0     0       517           208       150  ...           US
# 2        0     0       100          1807       738  ...           US
# 3        0     0       977           196       179  ...           US
# 4     1115     0       240          3684      2365  ...           US
#
#    dest_country_name aircraft_group aircraft_type aircraft_config  year  \
# 0      United States              6           824               1  2019
# 1      United States              6           631               1  2018
# 2      United States              6           675               1  2018
# 3      United States              6           675               1  2018
# 4      United States              6           631               1  2018
#
#    month  distance_group  class  data_source
# 0      7              12      F           IF
# 1     12               2      F           DU
# 2     11               1      F           DU
# 3      4               2      F           DU
# 4      4               1      F           DU
#
# [5 rows x 38 columns]

# %%
#Let dataframe show all columns
pd.set_option('display.max_columns', None)

# %%
#drop unnecessary columns
df_passengers = df_passengers_raw[['departures_performed', 'seats', 'passengers', 'distance', 'air_time', 'unique_carrier', 'airline_id',
                         'origin_airport_id', 'origin', 'dest_airport_id', 'dest', 'aircraft_group', 'aircraft_type', 'year', 'month']]
df_passengers.head()
# Out:
#    departures_performed  seats  passengers  distance  air_time unique_carrier  \
# 0                    22   6534        6096      5681         0             TP
# 1                     2    140          31       517       150             OO
# 2                    30   1500        1215       100       738             C5
# 3                     1     50          45       977       179             AX
# 4                    58   3734        2591       240      2365             OH
#
#    airline_id  origin_airport_id origin  dest_airport_id dest  aircraft_group  \
# 0       19576              12991    LIS            14771  SFO               6
# 1       20304              11292    DEN            14794  SGU               6
# 2       20445              12264    IAD            14524  RIC               6
# 3       20237              12339    IND            11292  DEN               6
# 4       20397              13930    ORD            11267  DAY               6
#
#    aircraft_type  year  month
# 0            824  2019      7
# 1            631  2018     12
# 2            675  2018     11
# 3            675  2018      4
# 4            631  2018      4

# %%
#Check for missing data
def check_null(df_passengers):
    total = df_passengers.isnull().sum().sort_values(ascending=False)
    percent = ((df_passengers.isnull().sum()/df_passengers.isnull().count()).sort_values(ascending=False))*100
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
check_null(df_passengers)
# Out:
#                       Total  Percent
# departures_performed      0      0.0
# seats                     0      0.0
# passengers                0      0.0
# distance                  0      0.0
# air_time                  0      0.0
# unique_carrier            0      0.0
# airline_id                0      0.0
# origin_airport_id         0      0.0
# origin                    0      0.0
# dest_airport_id           0      0.0
# dest                      0      0.0
# aircraft_group            0      0.0
# aircraft_type             0      0.0
# year                      0      0.0
# month                     0      0.0

# %%
#compare dimensions of dataframes
print(df_passengers.shape)
# Out:
# (50000, 15)

# %%
#export dataframe as a csv
df_passengers.to_csv('df_passengers_clean(2018).csv', index=False)
